# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students = {
    "Alice": {"age": 23, "score": 85},
    "Bob": {"age": 25, "score": 92},
    "Charlie": {"age": 22, "score": 88}
}

max_score=-1
max_student=""
age=-1
for student_name,student_score in students.items():
    if student_score['score']>max_score: 
        max_score=student_score['score']
        max_student=student_name
        
        
print(f"student Name:{max_student} and student Score:{max_score}")
# Out:
# student Name:Bob and student Score:92

# %%
import pandas as pd

# %%
df=pd.DataFrame(students).T
df
# Out:
#              name age score
# student1    Alice  28    85
# student2      Bob  22    92
# student3  Charlie  21    88

# %%
corresponding_row=df[df['age']==df['age'].max()]
corresponding_row
# Out:
#            name age score
# student1  Alice  28    85

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students_list = [
    {"name": "Alice", "age": 23, "score": 85},
    {"name": "Bob", "age": 25, "score": 92},
    {"name": "Charlie", "age": 22, "score": 88},
    {"name": "David", "age": 24, "score": 90}
]
students=[]
for student in students_list:
    if student['score']>90:
        students.append(student['name'])
print(students)
# Out:
# ['Bob']

# %%
df_list=pd.DataFrame(students_list)
df_list
# Out:
#       name  age  score
# 0    Alice   23     85
# 1      Bob   25     92
# 2  Charlie   22     88
# 3    David   24     90

# %%
df_filter=df_list[df_list['age']>23]
name=list(df_filter['name'])
name
# Out:
# ['Bob', 'David']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students_dict_list = {
    "name": ["Alice", "Bob", "Charlie", "David"],
    "age": [23, 25, 22, 24],
    "score": [85, 92, 88, 90]
}

# %%
result_score=[]
result_name=[]
student_age=students_dict_list['age']
student_name=students_dict_list['name']
student_score=students_dict_list['score']
for i in range(len(student_age)):
    if student_age[i]==24:
        result_name.append(student_name[i])
        result_score.append(student_score[i])
print(f"{result_score} and {result_name}")
# Out:
# [85] and ['Alice']

# %%
import pandas as pd
df=pd.DataFrame(students_dict_list)
df_filer=df[df['age']>23]
result=list(df_filter['name'])
print(result)
# Out:
# ['Bob', 'David']
