# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
today=pd.Timestamp.today()
print(today)
# Out:
# 2026-07-05 17:58:09.490308

# %%
data={
    "Name":["ANISH","NITISH","GEET"],
    "JoiningDate":pd.to_datetime([
        "2021-01-01",
        "2020-03-15",
        "2022-07-01"
    ])
}
df=pd.DataFrame(data)
df
# Out:
#      Name JoiningDate
# 0   ANISH  2021-01-01
# 1  NITISH  2020-03-15
# 2    GEET  2022-07-01

# %%
df_year=(today-df['JoiningDate'])
df_year
# Out:
# 0   2011 days 17:58:09.490308
# 1   2303 days 17:58:09.490308
# 2   1465 days 17:58:09.490308
# Name: JoiningDate, dtype: timedelta64[ns]

# %%
df_year=(today-df['JoiningDate']).dt.days
df_year
# Out:
# 0    2011
# 1    2303
# 2    1465
# Name: JoiningDate, dtype: int64

# %%
df_year=(today-df['JoiningDate']).dt.days
expe=df_year//365
expe
# Out:
# 0    5
# 1    6
# 2    4
# Name: JoiningDate, dtype: int64
