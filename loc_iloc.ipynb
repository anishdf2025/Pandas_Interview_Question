# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

data = {
    "ID": [1,2,3,4,5,6,7,8],
    "Name": ["Anish","Rahul","Priya","Sneha","Amit","Neha","Vikram","Pooja"],
    "Department": ["IT","HR","IT","Sales","HR","IT","Sales","Finance"],
    "Salary": [60000,45000,70000,50000,40000,65000,55000,48000],
    "Score": [85,70,92,88,60,95,76,81]
}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    ID   Name Department  Salary  Score
# 0   1  Anish         IT   60000     85
# 1   2  Rahul         HR   45000     70
# 2   3  Priya         IT   70000     92
# 3   4  Sneha      Sales   50000     88
# 4   5   Amit         HR   40000     60

# %%
df.tail()
# Out:
#    ID    Name Department  Salary  Score
# 3   4   Sneha      Sales   50000     88
# 4   5    Amit         HR   40000     60
# 5   6    Neha         IT   65000     95
# 6   7  Vikram      Sales   55000     76
# 7   8   Pooja    Finance   48000     81

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Department', 'Salary', 'Score'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          8 non-null      int64
#  1   Name        8 non-null      object
#  2   Department  8 non-null      object
#  3   Salary      8 non-null      int64
#  4   Score       8 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#             ID        Salary      Score
# count  8.00000      8.000000   8.000000
# mean   4.50000  54125.000000  80.875000
# std    2.44949  10301.698889  11.764808
# min    1.00000  40000.000000  60.000000
# 25%    2.75000  47250.000000  74.500000
# 50%    4.50000  52500.000000  83.000000
# 75%    6.25000  61250.000000  89.000000
# max    8.00000  70000.000000  95.000000

# %%
df.loc[0]
# Out:
# ID                1
# Name          Anish
# Department       IT
# Salary        60000
# Score            85
# Name: 0, dtype: object

# %%
df.loc[:,["Salary","Score"]]
# Out:
#    Salary  Score
# 0   60000     85
# 1   45000     70
# 2   70000     92
# 3   50000     88
# 4   40000     60
# 5   65000     95
# 6   55000     76
# 7   48000     81

# %% [markdown]
# # Update salary

# %%
df.loc[df["Department"] == "HR", "Salary"] = 60000
print(df)
# Out:
#    ID    Name Department  Salary  Score
# 0   1   Anish         IT   60000     85
# 1   2   Rahul         HR   60000     70
# 2   3   Priya         IT   70000     92
# 3   4   Sneha      Sales   50000     88
# 4   5    Amit         HR   60000     60
# 5   6    Neha         IT   65000     95
# 6   7  Vikram      Sales   55000     76
# 7   8   Pooja    Finance   48000     81

# %%
df.iloc[0]
# Out:
# ID                1
# Name          Anish
# Department       IT
# Salary        60000
# Score            85
# Name: 0, dtype: object

# %%
df.iloc[:,0:4]
# Out:
#    ID    Name Department  Salary
# 0   1   Anish         IT   60000
# 1   2   Rahul         HR   60000
# 2   3   Priya         IT   70000
# 3   4   Sneha      Sales   50000
# 4   5    Amit         HR   60000
# 5   6    Neha         IT   65000
# 6   7  Vikram      Sales   55000
# 7   8   Pooja    Finance   48000

# %%
df.iloc[2,0]
# Out:
# 3

# %% [markdown]
# 🔹 Example 5 — Update using iloc

# %%
df.iloc[2,3]=100

# %%
df.iloc[2,3]
# Out:
# 100
