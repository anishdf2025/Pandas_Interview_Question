# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
df=pd.read_excel("pandas_practice_data.xlsx")

# %%
df
# Out:
#     ID    Name Department   Salary  Score
# 0    1   Kiran  Marketing  82417.0   87.0
# 1    2  Vikram         HR  68718.0   64.0
# 2    3   Pooja  Marketing  59636.0   57.0
# 3    4   Kiran         HR  44930.0   78.0
# 4    5    Amit  Marketing  83359.0   52.0
# 5    6   Rahul         IT  40894.0    NaN
# 6    7   Rahul      Sales  72714.0   97.0
# 7    8   Pooja         HR  76861.0   66.0
# 8    9   Kiran         HR  62591.0   79.0
# 9   10   Pooja  Marketing      NaN   79.0
# 10  11   Rahul      Sales  67162.0   93.0
# 11  12  Vikram    Finance  31564.0   78.0
# 12  13    Neha  Marketing  78985.0   94.0
# 13  14   Kiran         IT  69440.0   79.0
# 14  15   Pooja    Finance  81949.0   62.0
# 15  16   Kiran         IT  77073.0   99.0
# 16  17    Amit         HR      NaN   58.0
# 17  18   Rahul      Sales  32341.0   60.0
# 18  19   Sneha      Sales  72994.0   84.0
# 19  20   Sneha    Finance  46100.0    NaN

# %%
df.head()
# Out:
#    ID    Name Department   Salary  Score
# 0   1   Kiran  Marketing  82417.0   87.0
# 1   2  Vikram         HR  68718.0   64.0
# 2   3   Pooja  Marketing  59636.0   57.0
# 3   4   Kiran         HR  44930.0   78.0
# 4   5    Amit  Marketing  83359.0   52.0

# %%
df.head()
# Out:
#    ID    Name Department   Salary  Score
# 0   1   Kiran  Marketing  82417.0   87.0
# 1   2  Vikram         HR  68718.0   64.0
# 2   3   Pooja  Marketing  59636.0   57.0
# 3   4   Kiran         HR  44930.0   78.0
# 4   5    Amit  Marketing  83359.0   52.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          20 non-null     int64
#  1   Name        20 non-null     object
#  2   Department  20 non-null     object
#  3   Salary      18 non-null     float64
#  4   Score       18 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 932.0+ bytes

# %%
df["Name"].isnull().sum()
# Out:
# 0

# %%
df["ID"].isnull().sum()
# Out:
# 0

# %%
df["Department"].isnull().sum()
# Out:
# 0

# %%
df["Salary"].isnull().sum()
# Out:
# 2

# %%
df["Score"].isnull().sum()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# ID            0
# Name          0
# Department    0
# Salary        2
# Score         2
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe()
# Out:
#              ID        Salary      Score
# count  20.00000     18.000000  18.000000
# mean   10.50000  63873.777778  75.888889
# std     5.91608  17335.361614  14.871563
# min     1.00000  31564.000000  52.000000
# 25%     5.75000  49484.000000  62.500000
# 50%    10.50000  69079.000000  78.500000
# 75%    15.25000  77020.000000  86.250000
# max    20.00000  83359.000000  99.000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe(include='object')
# Out:
#          Name Department
# count      20         20
# unique      7          5
# top     Kiran  Marketing
# freq        5          5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(df["Department"].unique())
# Out:
# ['Marketing' 'HR' 'IT' 'Sales' 'Finance']

# %%
print(df["Department"].value_counts())
# Out:
# Department
# Marketing    5
# HR           5
# Sales        4
# IT           3
# Finance      3
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df["Salary"].fillna(df["Salary"].mean(),inplace=True)

# %%
df
# Out:
#     ID    Name Department        Salary  Score
# 0    1   Kiran  Marketing  82417.000000   87.0
# 1    2  Vikram         HR  68718.000000   64.0
# 2    3   Pooja  Marketing  59636.000000   57.0
# 3    4   Kiran         HR  44930.000000   78.0
# 4    5    Amit  Marketing  83359.000000   52.0
# 5    6   Rahul         IT  40894.000000    NaN
# 6    7   Rahul      Sales  72714.000000   97.0
# 7    8   Pooja         HR  76861.000000   66.0
# 8    9   Kiran         HR  62591.000000   79.0
# 9   10   Pooja  Marketing  63873.777778   79.0
# 10  11   Rahul      Sales  67162.000000   93.0
# 11  12  Vikram    Finance  31564.000000   78.0
# 12  13    Neha  Marketing  78985.000000   94.0
# 13  14   Kiran         IT  69440.000000   79.0
# 14  15   Pooja    Finance  81949.000000   62.0
# 15  16   Kiran         IT  77073.000000   99.0
# 16  17    Amit         HR  63873.777778   58.0
# 17  18   Rahul      Sales  32341.000000   60.0
# 18  19   Sneha      Sales  72994.000000   84.0
# 19  20   Sneha    Finance  46100.000000    NaN

# %%
df["Score"].fillna(df["Score"].mean(),inplace=True)

# %%
df
# Out:
#     ID    Name Department        Salary      Score
# 0    1   Kiran  Marketing  82417.000000  87.000000
# 1    2  Vikram         HR  68718.000000  64.000000
# 2    3   Pooja  Marketing  59636.000000  57.000000
# 3    4   Kiran         HR  44930.000000  78.000000
# 4    5    Amit  Marketing  83359.000000  52.000000
# 5    6   Rahul         IT  40894.000000  75.888889
# 6    7   Rahul      Sales  72714.000000  97.000000
# 7    8   Pooja         HR  76861.000000  66.000000
# 8    9   Kiran         HR  62591.000000  79.000000
# 9   10   Pooja  Marketing  63873.777778  79.000000
# 10  11   Rahul      Sales  67162.000000  93.000000
# 11  12  Vikram    Finance  31564.000000  78.000000
# 12  13    Neha  Marketing  78985.000000  94.000000
# 13  14   Kiran         IT  69440.000000  79.000000
# 14  15   Pooja    Finance  81949.000000  62.000000
# 15  16   Kiran         IT  77073.000000  99.000000
# 16  17    Amit         HR  63873.777778  58.000000
# 17  18   Rahul      Sales  32341.000000  60.000000
# 18  19   Sneha      Sales  72994.000000  84.000000
# 19  20   Sneha    Finance  46100.000000  75.888889

# %%
df["Salary"].fillna(df["Salary"].median(),inplace=True)

# %%
df
# Out:
#     ID    Name Department        Salary      Score
# 0    1   Kiran  Marketing  82417.000000  87.000000
# 1    2  Vikram         HR  68718.000000  64.000000
# 2    3   Pooja  Marketing  59636.000000  57.000000
# 3    4   Kiran         HR  44930.000000  78.000000
# 4    5    Amit  Marketing  83359.000000  52.000000
# 5    6   Rahul         IT  40894.000000  75.888889
# 6    7   Rahul      Sales  72714.000000  97.000000
# 7    8   Pooja         HR  76861.000000  66.000000
# 8    9   Kiran         HR  62591.000000  79.000000
# 9   10   Pooja  Marketing  63873.777778  79.000000
# 10  11   Rahul      Sales  67162.000000  93.000000
# 11  12  Vikram    Finance  31564.000000  78.000000
# 12  13    Neha  Marketing  78985.000000  94.000000
# 13  14   Kiran         IT  69440.000000  79.000000
# 14  15   Pooja    Finance  81949.000000  62.000000
# 15  16   Kiran         IT  77073.000000  99.000000
# 16  17    Amit         HR  63873.777778  58.000000
# 17  18   Rahul      Sales  32341.000000  60.000000
# 18  19   Sneha      Sales  72994.000000  84.000000
# 19  20   Sneha    Finance  46100.000000  75.888889

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.dropna(subset=['Department'],inplace=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.dropna(inplace=True)

# %% [markdown]
# ![image.png](attachment:image.png)
