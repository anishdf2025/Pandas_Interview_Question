# %%
import pandas as pd
import numpy as np

data = {
    "EmployeeID": [101,102,103,104,105,106,107,108],
    "Name": ["Anish","Rahul","Priya","Amit","Neha","Rahul","Priya","Anish"],
    "Age": [24,28,26,np.nan,30,28,26,24],
    "Department": ["IT","HR","IT","Sales","HR","HR","IT","IT"],
    "Salary": [50000,60000,55000,45000,np.nan,60000,55000,50000],
    "Experience": [2,5,3,1,6,5,3,2],
    "Bonus": [5000,6000,5500,4500,7000,6000,5500,5000],
    "Gender": ["M","M","F","M","F","M","F","M"],
    "JoiningDate": pd.to_datetime([
        "2021-01-01","2020-03-15","2022-07-01","2023-02-20",
        "2019-10-11","2020-03-15","2022-07-01","2021-01-01"
    ]),
    "IsManager": [False,True,False,False,True,True,False,False]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    EmployeeID   Name   Age Department   Salary  Experience  Bonus Gender  \
# 0         101  Anish  24.0         IT  50000.0           2   5000      M
# 1         102  Rahul  28.0         HR  60000.0           5   6000      M
# 2         103  Priya  26.0         IT  55000.0           3   5500      F
# 3         104   Amit   NaN      Sales  45000.0           1   4500      M
# 4         105   Neha  30.0         HR      NaN           6   7000      F
# 5         106  Rahul  28.0         HR  60000.0           5   6000      M
# 6         107  Priya  26.0         IT  55000.0           3   5500      F
# 7         108  Anish  24.0         IT  50000.0           2   5000      M
#
#   JoiningDate  IsManager
# 0  2021-01-01      False
# 1  2020-03-15       True
# 2  2022-07-01      False
# 3  2023-02-20      False
# 4  2019-10-11       True
# 5  2020-03-15       True
# 6  2022-07-01      False
# 7  2021-01-01      False
